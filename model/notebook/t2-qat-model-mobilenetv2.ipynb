# %% [markdown]
# MobileNetV2 + Quantization Aware Training (QAT)
# Progressive 5-Phase Fine-Tuning
# ================================================
# Optimised for Kaggle Notebooks · GPU P100 (16 GB)
#
# * Phase 1 → All layers frozen       | FER-13  | lr = 7e-4
# * Phase 2 → Top 90 layers frozen     | FER-13  | lr = 7e-4
# * Phase 3 → Top 40 layers frozen     | FER-13  | lr = 3e-6
# * Phase 4 → Top 40 layers frozen     | RAF-DB  | lr = 3e-6
# * Phase 5 → Top 40 layers frozen     | AFD-DB  | lr = 5e-6
#
# Install (Kaggle already has TF 2.x; only tfmot may be missing):
#     pip install tensorflow-model-optimization -q
#
#     After installation, restart the kernal

# %%
# !pip install -q --upgrade numpy
# !pip install -q --upgrade tensorflow tensorflow-model-optimization
import importlib, pkg_resources
importlib.reload(pkg_resources)

# %%
# ══════════════════════════════════════════════════════════════════════
# USAGE NOTES
# ══════════════════════════════════════════════════════════════════════
#
# Kaggle notebook setup cell (run before this script):
# -------------------------------------------------------
# !pip install tensorflow-model-optimization -q
#
# Expected dataset structure (adjust paths in CONFIG section above):
# -------------------------------------------------------
# /kaggle/input/fer2013/
#   train/
#     angry/  disgust/  fear/  happy/  neutral/  sad/  surprise/
#   val/
#     angry/  disgust/  fear/  happy/  neutral/  sad/  surprise/
#
# /kaggle/input/raf-db/
#   train/  val/   (same class layout)
#
# All 4 phase .keras files + final_qat_int8.tflite land in:
#   /kaggle/working/qat_phases/
#
# TensorBoard (run in a separate cell):
# -------------------------------------------------------
# %load_ext tensorboard
# %tensorboard --logdir /kaggle/working/qat_phases/tb_logs
#
# P100 memory notes:
# -------------------------------------------------------
# • BATCH_SIZE=32 at 224×224 uses ~6 GB GPU RAM with QAT overhead.
# • Set BATCH_SIZE=16 if you add heavy augmentation or hit OOM.
# • Mixed precision (MIXED_PREC=True) cuts memory ~30% on P100.
# • ds.cache() is used; make sure /kaggle/working has enough disk.
#   If RAM is tight, remove .cache() from build_dataset().
# 
# ══════════════════════════════════════════════════════════════════════

# %% [markdown]
# # Import Library

# %%
# ── stdlib ─────────────────────────────────────────────────────────────
import os, gc, time, warnings
warnings.filterwarnings("ignore")

# %%
# ── third-party ────────────────────────────────────────────────────────
import numpy as np
import tensorflow as tf
import tensorflow_model_optimization as tfmot

print(f"TensorFlow  : {tf.__version__}")
print(f"tfmot       : {tfmot.__version__}")
print(f"GPU devices : {tf.config.list_physical_devices('GPU')}")
# Out:
# 2026-05-29 08:19:28.319923: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1780042768.342694     120 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1780042768.350247     120 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1780042768.368442     120 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780042768.368459     120 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780042768.368462     120 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780042768.368464     120 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# TensorFlow  : 2.19.1
# tfmot       : 0.8.1
# GPU devices : [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, accuracy_score, precision_score
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Configuration
#
# ## Dataset Path, Model input size, Training size, Phase Schedule

# %%
# ── Paths ──────────────────────────────────────────────────────────────
FER13_TRAIN  = "/kaggle/input/datasets/msambare/fer2013/train"
FER13_VAL    = "/kaggle/input/datasets/msambare/fer2013/test"
RAFDB_TRAIN  = "/kaggle/input/datasets/shuvoalok/raf-db-dataset/DATASET/train"
RAFDB_VAL    = "/kaggle/input/datasets/shuvoalok/raf-db-dataset/DATASET/test"
AFD_TRAIN    = "/kaggle/input/datasets/qystyy/asian-emotion-faces-split/dataset_split/train"
AFD_VAL      = "/kaggle/input/datasets/qystyy/asian-emotion-faces-split/dataset_split/test"
OUTPUT_DIR   = "/kaggle/working/qat_phases"

# ── Model ──────────────────────────────────────────────────────────────
NUM_CLASSES  = 7          # anger disgust fear happy neutral sad surprise
IMAGE_SIZE   = (224, 224)
CHANNELS     = 3

# ── Training ───────────────────────────────────────────────────────────
BATCH_SIZE   = 32         # safe for P100 16 GB at 224×224
MIXED_PREC   = True       # float16 activations → 2× throughput on P100

# ── Phase schedule ─────────────────────────────────────────────────────
#   (name, freeze_spec, dataset, lr, max_epochs, early_stop_patience)
#   freeze_spec: "ALL" | int N  (freeze layers 0..N-1)
PHASES = [                                                  # V2-9th Trial - To export the model zip folder for the model to run 
    ("phase1_all_frozen", "ALL",   "fer13",  7e-4, 15, 4),  # Change all the setting back to the same as 9th trial
    ("phase2_top90_frozen",  90,   "fer13",  7e-4, 15, 4),  # 
    ("phase3_top40_frozen",  40,   "fer13",  3e-6, 30, 5),  # 
    ("phase4_rafdb",         40,   "rafdb",  3e-6, 75, 5),  # 
    ("phase5_afd",           40,   "afd",    5e-6, 120, 5), # 
]
os.makedirs(OUTPUT_DIR, exist_ok=True)
print('Config OK - output dir:', OUTPUT_DIR)
# Out:
# Config OK - output dir: /kaggle/working/qat_phases

# %% [markdown]
# # Dataset
#
# ## Dataset Augmentation

# %%
def augment_train(image, label):
    """
    Light augmentation — enough to regularise without destroying subtle
    facial expressions.  Keep it mild because QAT already introduces
    extra noise via fake-quant ops.
    """
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_brightness(image, max_delta=0.12)
    image = tf.image.random_contrast(image, lower=0.88, upper=1.12)
    # Mild random crop: zoom in up to 10 %
    shape  = tf.shape(image)
    crop_h = tf.cast(tf.cast(shape[0], tf.float32) * 0.92, tf.int32)
    crop_w = tf.cast(tf.cast(shape[1], tf.float32) * 0.92, tf.int32)
    image  = tf.image.resize(image, IMAGE_SIZE)
    image  = tf.clip_by_value(image, 0.0, 1.0)
    return image, label

print("Data aug done")
# Out:
# Data aug done

# %%
# FER-13 alphabetical order — Keras default, no remapping needed
FER13_CLASSES = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# RAF-DB: folder name → correct emotion index (matching FER-13 order above)
# RAF-DB numbering: 1=Surprise,2=Fear,3=Disgust,4=Happy,5=Sad,6=Angry,7=Neutral
RAFDB_FOLDER_TO_EMOTION = {
    '1': 6,   # Surprise → index 6
    '2': 2,   # Fear     → index 2
    '3': 1,   # Disgust  → index 1
    '4': 3,   # Happy    → index 3
    '5': 5,   # Sad      → index 5
    '6': 0,   # Angry    → index 0
    '7': 4,   # Neutral  → index 4
}


def build_dataset(directory, training, class_mapping=None):
    """
    class_mapping: dict {original_index: correct_index}
                   None = use Keras alphabetical order as-is (FER-13)
    """
    ds = tf.keras.utils.image_dataset_from_directory(
        directory,
        image_size=IMAGE_SIZE,
        batch_size=BATCH_SIZE,
        label_mode='categorical',
        shuffle=training,
        seed=42,
        interpolation='bilinear',
    )

    # Remap labels if a mapping is provided
    if class_mapping is not None:
        # Build a lookup tensor: index i → correct index
        n_classes  = NUM_CLASSES
        lookup     = np.zeros(n_classes, dtype=np.int32)
        for orig, correct in class_mapping.items():
            lookup[int(orig)] = correct
        lookup_tensor = tf.constant(lookup, dtype=tf.int32)

        def remap_labels(images, labels):
            # labels shape: (batch, n_classes) one-hot
            orig_indices  = tf.argmax(labels, axis=1, output_type=tf.int32)
            new_indices   = tf.gather(lookup_tensor, orig_indices)
            new_labels    = tf.one_hot(new_indices, depth=n_classes)
            return images, new_labels

        ds = ds.map(remap_labels, num_parallel_calls=tf.data.AUTOTUNE)

    # Normalise
    ds = ds.map(lambda x, y: (tf.cast(x, tf.float32) / 255.0, y),
                num_parallel_calls=tf.data.AUTOTUNE)
    if training:
        ds = ds.map(augment_train, num_parallel_calls=tf.data.AUTOTUNE)

    ds = ds.prefetch(tf.data.AUTOTUNE)
    return ds


def get_datasets(name):
    if name == 'fer13':
        return build_dataset(FER13_TRAIN, True), build_dataset(FER13_VAL, False)
    elif name == 'rafdb':
        # Build index mapping: Keras assigns 0..6 alphabetically to '1'..'7'
        # so original index = folder_name - 1
        index_mapping = {i: RAFDB_FOLDER_TO_EMOTION[str(i+1)] for i in range(7)}
        return (build_dataset(RAFDB_TRAIN, True,  index_mapping),
                build_dataset(RAFDB_VAL,   False, index_mapping))
    elif name == 'afd':
        return build_dataset(AFD_TRAIN, True), build_dataset(AFD_VAL, False)
    elif name == 'vea':
        return build_dataset(VEA_TRAIN, True), build_dataset(VEA_VAL, False)
    raise ValueError(f'Unknown dataset: {name}')

print('Dataset pipeline ready.')
# Out:
# Dataset pipeline ready.

# %%
# Sanity check — print a few label distributions per dataset
for name in ['fer13', 'rafdb','afd']:
    train_ds, _ = get_datasets(name)
    label_counts = np.zeros(NUM_CLASSES, dtype=int)
    for _, labels in train_ds.take(20):
        indices = np.argmax(labels.numpy(), axis=1)
        for idx in indices:
            label_counts[idx] += 1
    print(f'\n{name} label sample (first 20 batches):')
    for i, (emotion, count) in enumerate(zip(FER13_CLASSES, label_counts)):
        print(f'  {i} {emotion:<10} : {count}')
# Out:
# Found 28709 files belonging to 7 classes.
# I0000 00:00:1780042816.963355     120 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Found 7178 files belonging to 7 classes.
#
# fer13 label sample (first 20 batches):
#   0 angry      : 71
#   1 disgust    : 17
#   2 fear       : 95
#   3 happy      : 187
#   4 neutral    : 105
#   5 sad        : 108
#   6 surprise   : 57
# Found 12271 files belonging to 7 classes.
# Found 3068 files belonging to 7 classes.
#
# rafdb label sample (first 20 batches):
#   0 angry      : 41
#   1 disgust    : 39
#   2 fear       : 11
#   3 happy      : 229
#   4 neutral    : 123
#   5 sad        : 125
#   6 surprise   : 72
# Found 672 files belonging to 7 classes.
# Found 168 files belonging to 7 classes.
#
# afd label sample (first 20 batches):
#   0 angry      : 93
#   1 disgust    : 93
#   2 fear       : 93
#   3 happy      : 92
#   4 neutral    : 89
#   5 sad        : 90
#   6 surprise   : 90

# %% [markdown]
# # Base Model
#
# MobileNetV2 pretrained on ImageNet.
# Custom head: GlobalAvgPool → BN → Dropout → Dense(NUM_CLASSES).
#
# Notes for QAT compatibility:
#
# * Use ReLU6 activations (MobileNetV2 default) — they quantise cleanly.
# * Avoid Lambda layers; they break QAT graph tracing.
# * The final Dense uses float32 output even under mixed precision  (required for stable softmax / loss computation)

# %%
# 1. Build base model
base_model = tf.keras.applications.MobileNetV2(
    input_shape=(*IMAGE_SIZE, CHANNELS),
    include_top=False,
    weights='imagenet',
)

x = tf.keras.layers.GlobalAveragePooling2D()(base_model.output)  # (None, 1280)
x = tf.keras.layers.Dense(512, activation='relu')(x)
x = tf.keras.layers.Dropout(0.4)(x)
x = tf.keras.layers.Dense(256, activation='relu')(x)
x = tf.keras.layers.Dropout(0.3)(x)
output = tf.keras.layers.Dense(
    NUM_CLASSES,
    activation='softmax',
    dtype='float32',
    name='predictions',
)(x)

model = tf.keras.Model(base_model.input, outputs=output, name='MobileNetV2_QAT')

# 2. Save the clean base model BEFORE quantizing
base_save_path = os.path.join(OUTPUT_DIR, 'base_model.keras')
model.save(base_save_path)
print('Base model saved.')

print(f'Total layers : {len(model.layers)}')
print(f'Total params : {model.count_params():,}')
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 2s 0us/step
# Base model saved.
# Total layers : 160
# Total params : 3,046,983
# Model: "MobileNetV2_QAT"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  Conv1 (Conv2D)              (None, 112, 112, 32)         864       ['input_1[0][0]']
#
#  bn_Conv1 (BatchNormalizati  (None, 112, 112, 32)         128       ['Conv1[0][0]']
#  on)
#
#  Conv1_relu (ReLU)           (None, 112, 112, 32)         0         ['bn_Conv1[0][0]']
#
#  expanded_conv_depthwise (D  (None, 112, 112, 32)         288       ['Conv1_relu[0][0]']
#  epthwiseConv2D)
#
#  expanded_conv_depthwise_BN  (None, 112, 112, 32)         128       ['expanded_conv_depthwise[0][0
#   (BatchNormalization)                                              ]']
#
#  expanded_conv_depthwise_re  (None, 112, 112, 32)         0         ['expanded_conv_depthwise_BN[0
#  lu (ReLU)                                                          ][0]']
#
#  expanded_conv_project (Con  (None, 112, 112, 16)         512       ['expanded_conv_depthwise_relu
#  v2D)                                                               [0][0]']
#
#  expanded_conv_project_BN (  (None, 112, 112, 16)         64        ['expanded_conv_project[0][0]'
#  BatchNormalization)                                                ]
#
#  block_1_expand (Conv2D)     (None, 112, 112, 96)         1536      ['expanded_conv_project_BN[0][
#                                                                     0]']
#
#  block_1_expand_BN (BatchNo  (None, 112, 112, 96)         384       ['block_1_expand[0][0]']
#  rmalization)
#
#  block_1_expand_relu (ReLU)  (None, 112, 112, 96)         0         ['block_1_expand_BN[0][0]']
#
#  block_1_pad (ZeroPadding2D  (None, 113, 113, 96)         0         ['block_1_expand_relu[0][0]']
#  )
#
#  block_1_depthwise (Depthwi  (None, 56, 56, 96)           864       ['block_1_pad[0][0]']
#  seConv2D)
#
#  block_1_depthwise_BN (Batc  (None, 56, 56, 96)           384       ['block_1_depthwise[0][0]']
#  hNormalization)
#
#  block_1_depthwise_relu (Re  (None, 56, 56, 96)           0         ['block_1_depthwise_BN[0][0]']
#  LU)
#
#  block_1_project (Conv2D)    (None, 56, 56, 24)           2304      ['block_1_depthwise_relu[0][0]
#                                                                     ']
#
#  block_1_project_BN (BatchN  (None, 56, 56, 24)           96        ['block_1_project[0][0]']
#  ormalization)
#
#  block_2_expand (Conv2D)     (None, 56, 56, 144)          3456      ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNo  (None, 56, 56, 144)          576       ['block_2_expand[0][0]']
#  rmalization)
#
#  block_2_expand_relu (ReLU)  (None, 56, 56, 144)          0         ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (Depthwi  (None, 56, 56, 144)          1296      ['block_2_expand_relu[0][0]']
#  seConv2D)
#
#  block_2_depthwise_BN (Batc  (None, 56, 56, 144)          576       ['block_2_depthwise[0][0]']
#  hNormalization)
#
#  block_2_depthwise_relu (Re  (None, 56, 56, 144)          0         ['block_2_depthwise_BN[0][0]']
#  LU)
#
#  block_2_project (Conv2D)    (None, 56, 56, 24)           3456      ['block_2_depthwise_relu[0][0]
#                                                                     ']
#
#  block_2_project_BN (BatchN  (None, 56, 56, 24)           96        ['block_2_project[0][0]']
#  ormalization)
#
#  block_2_add (Add)           (None, 56, 56, 24)           0         ['block_1_project_BN[0][0]',
#                                                                      'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)     (None, 56, 56, 144)          3456      ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNo  (None, 56, 56, 144)          576       ['block_3_expand[0][0]']
#  rmalization)
#
#  block_3_expand_relu (ReLU)  (None, 56, 56, 144)          0         ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D  (None, 57, 57, 144)          0         ['block_3_expand_relu[0][0]']
#  )
#
#  block_3_depthwise (Depthwi  (None, 28, 28, 144)          1296      ['block_3_pad[0][0]']
#  seConv2D)
#
#  block_3_depthwise_BN (Batc  (None, 28, 28, 144)          576       ['block_3_depthwise[0][0]']
#  hNormalization)
#
#  block_3_depthwise_relu (Re  (None, 28, 28, 144)          0         ['block_3_depthwise_BN[0][0]']
#  LU)
#
#  block_3_project (Conv2D)    (None, 28, 28, 32)           4608      ['block_3_depthwise_relu[0][0]
#                                                                     ']
#
#  block_3_project_BN (BatchN  (None, 28, 28, 32)           128       ['block_3_project[0][0]']
#  ormalization)
#
#  block_4_expand (Conv2D)     (None, 28, 28, 192)          6144      ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNo  (None, 28, 28, 192)          768       ['block_4_expand[0][0]']
#  rmalization)
#
#  block_4_expand_relu (ReLU)  (None, 28, 28, 192)          0         ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (Depthwi  (None, 28, 28, 192)          1728      ['block_4_expand_relu[0][0]']
#  seConv2D)
#
#  block_4_depthwise_BN (Batc  (None, 28, 28, 192)          768       ['block_4_depthwise[0][0]']
#  hNormalization)
#
#  block_4_depthwise_relu (Re  (None, 28, 28, 192)          0         ['block_4_depthwise_BN[0][0]']
#  LU)
#
#  block_4_project (Conv2D)    (None, 28, 28, 32)           6144      ['block_4_depthwise_relu[0][0]
#                                                                     ']
#
#  block_4_project_BN (BatchN  (None, 28, 28, 32)           128       ['block_4_project[0][0]']
#  ormalization)
#
#  block_4_add (Add)           (None, 28, 28, 32)           0         ['block_3_project_BN[0][0]',
#                                                                      'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)     (None, 28, 28, 192)          6144      ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNo  (None, 28, 28, 192)          768       ['block_5_expand[0][0]']
#  rmalization)
#
#  block_5_expand_relu (ReLU)  (None, 28, 28, 192)          0         ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (Depthwi  (None, 28, 28, 192)          1728      ['block_5_expand_relu[0][0]']
#  seConv2D)
#
#  block_5_depthwise_BN (Batc  (None, 28, 28, 192)          768       ['block_5_depthwise[0][0]']
#  hNormalization)
#
#  block_5_depthwise_relu (Re  (None, 28, 28, 192)          0         ['block_5_depthwise_BN[0][0]']
#  LU)
#
#  block_5_project (Conv2D)    (None, 28, 28, 32)           6144      ['block_5_depthwise_relu[0][0]
#                                                                     ']
#
#  block_5_project_BN (BatchN  (None, 28, 28, 32)           128       ['block_5_project[0][0]']
#  ormalization)
#
#  block_5_add (Add)           (None, 28, 28, 32)           0         ['block_4_add[0][0]',
#                                                                      'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)     (None, 28, 28, 192)          6144      ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNo  (None, 28, 28, 192)          768       ['block_6_expand[0][0]']
#  rmalization)
#
#  block_6_expand_relu (ReLU)  (None, 28, 28, 192)          0         ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D  (None, 29, 29, 192)          0         ['block_6_expand_relu[0][0]']
#  )
#
#  block_6_depthwise (Depthwi  (None, 14, 14, 192)          1728      ['block_6_pad[0][0]']
#  seConv2D)
#
#  block_6_depthwise_BN (Batc  (None, 14, 14, 192)          768       ['block_6_depthwise[0][0]']
#  hNormalization)
#
#  block_6_depthwise_relu (Re  (None, 14, 14, 192)          0         ['block_6_depthwise_BN[0][0]']
#  LU)
#
#  block_6_project (Conv2D)    (None, 14, 14, 64)           12288     ['block_6_depthwise_relu[0][0]
#                                                                     ']
#
#  block_6_project_BN (BatchN  (None, 14, 14, 64)           256       ['block_6_project[0][0]']
#  ormalization)
#
#  block_7_expand (Conv2D)     (None, 14, 14, 384)          24576     ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNo  (None, 14, 14, 384)          1536      ['block_7_expand[0][0]']
#  rmalization)
#
#  block_7_expand_relu (ReLU)  (None, 14, 14, 384)          0         ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (Depthwi  (None, 14, 14, 384)          3456      ['block_7_expand_relu[0][0]']
#  seConv2D)
#
#  block_7_depthwise_BN (Batc  (None, 14, 14, 384)          1536      ['block_7_depthwise[0][0]']
#  hNormalization)
#
#  block_7_depthwise_relu (Re  (None, 14, 14, 384)          0         ['block_7_depthwise_BN[0][0]']
#  LU)
#
#  block_7_project (Conv2D)    (None, 14, 14, 64)           24576     ['block_7_depthwise_relu[0][0]
#                                                                     ']
#
#  block_7_project_BN (BatchN  (None, 14, 14, 64)           256       ['block_7_project[0][0]']
#  ormalization)
#
#  block_7_add (Add)           (None, 14, 14, 64)           0         ['block_6_project_BN[0][0]',
#                                                                      'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)     (None, 14, 14, 384)          24576     ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNo  (None, 14, 14, 384)          1536      ['block_8_expand[0][0]']
#  rmalization)
#
#  block_8_expand_relu (ReLU)  (None, 14, 14, 384)          0         ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (Depthwi  (None, 14, 14, 384)          3456      ['block_8_expand_relu[0][0]']
#  seConv2D)
#
#  block_8_depthwise_BN (Batc  (None, 14, 14, 384)          1536      ['block_8_depthwise[0][0]']
#  hNormalization)
#
#  block_8_depthwise_relu (Re  (None, 14, 14, 384)          0         ['block_8_depthwise_BN[0][0]']
#  LU)
#
#  block_8_project (Conv2D)    (None, 14, 14, 64)           24576     ['block_8_depthwise_relu[0][0]
#                                                                     ']
#
#  block_8_project_BN (BatchN  (None, 14, 14, 64)           256       ['block_8_project[0][0]']
#  ormalization)
#
#  block_8_add (Add)           (None, 14, 14, 64)           0         ['block_7_add[0][0]',
#                                                                      'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)     (None, 14, 14, 384)          24576     ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNo  (None, 14, 14, 384)          1536      ['block_9_expand[0][0]']
#  rmalization)
#
#  block_9_expand_relu (ReLU)  (None, 14, 14, 384)          0         ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (Depthwi  (None, 14, 14, 384)          3456      ['block_9_expand_relu[0][0]']
#  seConv2D)
#
#  block_9_depthwise_BN (Batc  (None, 14, 14, 384)          1536      ['block_9_depthwise[0][0]']
#  hNormalization)
#
#  block_9_depthwise_relu (Re  (None, 14, 14, 384)          0         ['block_9_depthwise_BN[0][0]']
#  LU)
#
#  block_9_project (Conv2D)    (None, 14, 14, 64)           24576     ['block_9_depthwise_relu[0][0]
#                                                                     ']
#
#  block_9_project_BN (BatchN  (None, 14, 14, 64)           256       ['block_9_project[0][0]']
#  ormalization)
#
#  block_9_add (Add)           (None, 14, 14, 64)           0         ['block_8_add[0][0]',
#                                                                      'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)    (None, 14, 14, 384)          24576     ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchN  (None, 14, 14, 384)          1536      ['block_10_expand[0][0]']
#  ormalization)
#
#  block_10_expand_relu (ReLU  (None, 14, 14, 384)          0         ['block_10_expand_BN[0][0]']
#  )
#
#  block_10_depthwise (Depthw  (None, 14, 14, 384)          3456      ['block_10_expand_relu[0][0]']
#  iseConv2D)
#
#  block_10_depthwise_BN (Bat  (None, 14, 14, 384)          1536      ['block_10_depthwise[0][0]']
#  chNormalization)
#
#  block_10_depthwise_relu (R  (None, 14, 14, 384)          0         ['block_10_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_10_project (Conv2D)   (None, 14, 14, 96)           36864     ['block_10_depthwise_relu[0][0
#                                                                     ]']
#
#  block_10_project_BN (Batch  (None, 14, 14, 96)           384       ['block_10_project[0][0]']
#  Normalization)
#
#  block_11_expand (Conv2D)    (None, 14, 14, 576)          55296     ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchN  (None, 14, 14, 576)          2304      ['block_11_expand[0][0]']
#  ormalization)
#
#  block_11_expand_relu (ReLU  (None, 14, 14, 576)          0         ['block_11_expand_BN[0][0]']
#  )
#
#  block_11_depthwise (Depthw  (None, 14, 14, 576)          5184      ['block_11_expand_relu[0][0]']
#  iseConv2D)
#
#  block_11_depthwise_BN (Bat  (None, 14, 14, 576)          2304      ['block_11_depthwise[0][0]']
#  chNormalization)
#
#  block_11_depthwise_relu (R  (None, 14, 14, 576)          0         ['block_11_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_11_project (Conv2D)   (None, 14, 14, 96)           55296     ['block_11_depthwise_relu[0][0
#                                                                     ]']
#
#  block_11_project_BN (Batch  (None, 14, 14, 96)           384       ['block_11_project[0][0]']
#  Normalization)
#
#  block_11_add (Add)          (None, 14, 14, 96)           0         ['block_10_project_BN[0][0]',
#                                                                      'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)    (None, 14, 14, 576)          55296     ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchN  (None, 14, 14, 576)          2304      ['block_12_expand[0][0]']
#  ormalization)
#
#  block_12_expand_relu (ReLU  (None, 14, 14, 576)          0         ['block_12_expand_BN[0][0]']
#  )
#
#  block_12_depthwise (Depthw  (None, 14, 14, 576)          5184      ['block_12_expand_relu[0][0]']
#  iseConv2D)
#
#  block_12_depthwise_BN (Bat  (None, 14, 14, 576)          2304      ['block_12_depthwise[0][0]']
#  chNormalization)
#
#  block_12_depthwise_relu (R  (None, 14, 14, 576)          0         ['block_12_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_12_project (Conv2D)   (None, 14, 14, 96)           55296     ['block_12_depthwise_relu[0][0
#                                                                     ]']
#
#  block_12_project_BN (Batch  (None, 14, 14, 96)           384       ['block_12_project[0][0]']
#  Normalization)
#
#  block_12_add (Add)          (None, 14, 14, 96)           0         ['block_11_add[0][0]',
#                                                                      'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)    (None, 14, 14, 576)          55296     ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchN  (None, 14, 14, 576)          2304      ['block_13_expand[0][0]']
#  ormalization)
#
#  block_13_expand_relu (ReLU  (None, 14, 14, 576)          0         ['block_13_expand_BN[0][0]']
#  )
#
#  block_13_pad (ZeroPadding2  (None, 15, 15, 576)          0         ['block_13_expand_relu[0][0]']
#  D)
#
#  block_13_depthwise (Depthw  (None, 7, 7, 576)            5184      ['block_13_pad[0][0]']
#  iseConv2D)
#
#  block_13_depthwise_BN (Bat  (None, 7, 7, 576)            2304      ['block_13_depthwise[0][0]']
#  chNormalization)
#
#  block_13_depthwise_relu (R  (None, 7, 7, 576)            0         ['block_13_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_13_project (Conv2D)   (None, 7, 7, 160)            92160     ['block_13_depthwise_relu[0][0
#                                                                     ]']
#
#  block_13_project_BN (Batch  (None, 7, 7, 160)            640       ['block_13_project[0][0]']
#  Normalization)
#
#  block_14_expand (Conv2D)    (None, 7, 7, 960)            153600    ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchN  (None, 7, 7, 960)            3840      ['block_14_expand[0][0]']
#  ormalization)
#
#  block_14_expand_relu (ReLU  (None, 7, 7, 960)            0         ['block_14_expand_BN[0][0]']
#  )
#
#  block_14_depthwise (Depthw  (None, 7, 7, 960)            8640      ['block_14_expand_relu[0][0]']
#  iseConv2D)
#
#  block_14_depthwise_BN (Bat  (None, 7, 7, 960)            3840      ['block_14_depthwise[0][0]']
#  chNormalization)
#
#  block_14_depthwise_relu (R  (None, 7, 7, 960)            0         ['block_14_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_14_project (Conv2D)   (None, 7, 7, 160)            153600    ['block_14_depthwise_relu[0][0
#                                                                     ]']
#
#  block_14_project_BN (Batch  (None, 7, 7, 160)            640       ['block_14_project[0][0]']
#  Normalization)
#
#  block_14_add (Add)          (None, 7, 7, 160)            0         ['block_13_project_BN[0][0]',
#                                                                      'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)    (None, 7, 7, 960)            153600    ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchN  (None, 7, 7, 960)            3840      ['block_15_expand[0][0]']
#  ormalization)
#
#  block_15_expand_relu (ReLU  (None, 7, 7, 960)            0         ['block_15_expand_BN[0][0]']
#  )
#
#  block_15_depthwise (Depthw  (None, 7, 7, 960)            8640      ['block_15_expand_relu[0][0]']
#  iseConv2D)
#
#  block_15_depthwise_BN (Bat  (None, 7, 7, 960)            3840      ['block_15_depthwise[0][0]']
#  chNormalization)
#
#  block_15_depthwise_relu (R  (None, 7, 7, 960)            0         ['block_15_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_15_project (Conv2D)   (None, 7, 7, 160)            153600    ['block_15_depthwise_relu[0][0
#                                                                     ]']
#
#  block_15_project_BN (Batch  (None, 7, 7, 160)            640       ['block_15_project[0][0]']
#  Normalization)
#
#  block_15_add (Add)          (None, 7, 7, 160)            0         ['block_14_add[0][0]',
#                                                                      'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)    (None, 7, 7, 960)            153600    ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchN  (None, 7, 7, 960)            3840      ['block_16_expand[0][0]']
#  ormalization)
#
#  block_16_expand_relu (ReLU  (None, 7, 7, 960)            0         ['block_16_expand_BN[0][0]']
#  )
#
#  block_16_depthwise (Depthw  (None, 7, 7, 960)            8640      ['block_16_expand_relu[0][0]']
#  iseConv2D)
#
#  block_16_depthwise_BN (Bat  (None, 7, 7, 960)            3840      ['block_16_depthwise[0][0]']
#  chNormalization)
#
#  block_16_depthwise_relu (R  (None, 7, 7, 960)            0         ['block_16_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_16_project (Conv2D)   (None, 7, 7, 320)            307200    ['block_16_depthwise_relu[0][0
#                                                                     ]']
#
#  block_16_project_BN (Batch  (None, 7, 7, 320)            1280      ['block_16_project[0][0]']
#  Normalization)
#
#  Conv_1 (Conv2D)             (None, 7, 7, 1280)           409600    ['block_16_project_BN[0][0]']
#
#  Conv_1_bn (BatchNormalizat  (None, 7, 7, 1280)           5120      ['Conv_1[0][0]']
#  ion)
#
#  out_relu (ReLU)             (None, 7, 7, 1280)           0         ['Conv_1_bn[0][0]']
#
#  global_average_pooling2d (  (None, 1280)                 0         ['out_relu[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 512)                  655872    ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dropout (Dropout)           (None, 512)                  0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 256)                  131328    ['dropout[0][0]']
#
#  dropout_1 (Dropout)         (None, 256)                  0         ['dense_1[0][0]']
#
#  predictions (Dense)         (None, 7)                    1799      ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 3046983 (11.62 MB)
# Trainable params: 3012871 (11.49 MB)
# Non-trainable params: 34112 (133.25 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# # QAT (RUN ONCE ONLY)
#
#     Insert fake-quantisation nodes throughout the model graph.
#
#     Key detail for MobileNetV2:
#       tfmot.quantize_model() handles DepthwiseConv2D and BatchNorm correctly
#       in TF ≥ 2.9 — it folds BN into the preceding conv for inference
#       and inserts observer nodes for weight + activation quantisation.
#
#     The returned model has the SAME layer structure but every eligible
#     op now has a fake-quant wrapper.  Frozen layers still participate
#     in the forward pass (fake-quant active) but receive no gradients.

# %%
# ══════════════════════════════════════════════════════════════════════
# 5.  QAT WRAPPER  (RUN ONCE ONLY)
# ══════════════════════════════════════════════════════════════════════
print('Inserting fake-quantisation nodes ...')
model = tfmot.quantization.keras.quantize_model(model)
print(f'QAT model — layers after wrapping: {len(model.layers)}')
print('Fake-quant nodes inserted. QAT wrapper will be carried through all phases.')
# Out:
# Inserting fake-quantisation nodes ...
# QAT model — layers after wrapping: 161
# Fake-quant nodes inserted. QAT wrapper will be carried through all phases.

# %% [markdown]
# ## Base model freeze

# %%
def apply_freeze(model, freeze_spec):
    """
    freeze_spec = 'ALL'  → freeze every layer
    freeze_spec = int N  → freeze layers 0..N-1, unfreeze N..end
    Must recompile after calling this.
    """
    if freeze_spec == 'ALL':
        for layer in model.layers:
            layer.trainable = False
        n_frozen, n_trainable = len(model.layers), 0
    else:
        n = int(freeze_spec)
        for i, layer in enumerate(model.layers):
            layer.trainable = (i >= n)
        n_frozen    = n
        n_trainable = len(model.layers) - n

    trainable_params = int(np.sum([np.prod(w.shape) for w in model.trainable_weights]))
    print(f'  Frozen / trainable layers : {n_frozen} / {n_trainable}')
    print(f'  Trainable parameters      : {trainable_params:,}')
    return model

# %% [markdown]
# # Callbacks

# %%
def build_callbacks(phase_name, patience, lr):
    best_ckpt = os.path.join(OUTPUT_DIR, f'{phase_name}_best.keras')

    if os.path.exists(best_ckpt):
        os.remove(best_ckpt)

    return [
        tf.keras.callbacks.ModelCheckpoint(
            filepath=best_ckpt,
            monitor='val_accuracy',
            save_best_only=True,
            save_weights_only=False,   # full model preserves QAT graph
            verbose=1,
        ),
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=patience,
            restore_best_weights=True,
            min_delta=0.0005,
            verbose=1,
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.5,
            patience=max(1, patience // 2),
            min_lr=lr * 1e-3,
            verbose=1,
        ),
        tf.keras.callbacks.CSVLogger(
            os.path.join(OUTPUT_DIR, f'{phase_name}_log.csv'),
        ),
        tf.keras.callbacks.TensorBoard(
            log_dir=os.path.join(OUTPUT_DIR, 'tb_logs', phase_name),
            update_freq='epoch',
        ),
        EpochSummary(),
    ], best_ckpt

# %%
class EpochSummary(tf.keras.callbacks.Callback):
    """One-line per-epoch print so verbose=0 still shows progress."""
    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        lr   = float(tf.keras.backend.get_value(self.model.optimizer.lr))
        print(
            f'  ep {epoch+1:03d} | '
            f'loss={logs.get("loss", 0):.4f} | '
            f'acc={logs.get("accuracy", 0):.4f} | '
            f'val_loss={logs.get("val_loss", 0):.4f} | '
            f'val_acc={logs.get("val_accuracy", 0):.4f} | '
            f'lr={lr:.2e}'
        )

# %% [markdown]
# # Class Weight

# %%
def compute_class_weights(dataset_name):
    """
    Auto-compute class weights from the training directory.
    Returns a dict {class_index: weight} ready for model.fit(class_weight=...)
    """
    if dataset_name == 'fer13':
        train_dir = FER13_TRAIN
    elif dataset_name == 'rafdb':
        train_dir = RAFDB_TRAIN
    elif dataset_name == 'afd':
        train_dir = AFD_TRAIN
    else:
        raise ValueError(f'Unknown dataset: {dataset_name}')

    # Count samples per class by scanning the folder
    class_names = sorted(os.listdir(train_dir))   # alphabetical — matches Keras label order
    class_counts = []
    for cls in class_names:
        cls_path = os.path.join(train_dir, cls)
        if os.path.isdir(cls_path):
            class_counts.append(len(os.listdir(cls_path)))

    total_samples = sum(class_counts)
    labels_expanded = []
    for idx, count in enumerate(class_counts):
        labels_expanded.extend([idx] * count)

    weights = compute_class_weight(
        class_weight='balanced',
        classes=np.arange(len(class_names)),
        y=np.array(labels_expanded),
    )

    class_weight_dict = dict(enumerate(weights))

    # Print breakdown so you can see what weights were assigned
    print(f'\n[Class Weights] Dataset: {dataset_name}  |  Total samples: {total_samples}')
    print(f'  {"Class":<12} {"Count":>7}  {"Weight":>8}')
    print(f'  {"-"*30}')
    for idx, (cls, count, w) in enumerate(zip(class_names, class_counts, weights)):
        bar = '█' * int(w * 6)
        print(f'  {cls:<12} {count:>7}  {w:>8.4f}  {bar}')

    return class_weight_dict

# %% [markdown]
# # Model Training
#
# ## Phase 1 — All layers frozen | FER-13 | lr = 7e-4
# QAT scale calibration pass. The whole backbone is frozen — only the
# fake-quant observers are learning the weight/activation ranges.

# %%
phase_name, freeze_spec, dataset, lr, max_epochs, patience = PHASES[0]
print(f'=== {phase_name.upper()} ===')

# ✅ Always rebuild QAT model fresh each phase to avoid stale HDF5 state
with tfmot.quantization.keras.quantize_scope():
    model = tf.keras.models.load_model(base_save_path)

model = apply_freeze(model, freeze_spec)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=lr, epsilon=1e-7),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=['accuracy', tf.keras.metrics.Precision(name='precision')],
)

train_ds, val_ds = get_datasets(dataset)
callbacks_p1, best_ckpt_p1 = build_callbacks(phase_name, patience, lr)
cw = compute_class_weights(dataset)

t0 = time.time()
history_p1 = model.fit(
    train_ds, validation_data=val_ds,
    epochs=max_epochs, callbacks=callbacks_p1, class_weight=cw,
)

print(f'\nPhase 1 done in {(time.time()-t0)/60:.1f} min')
print(f'Best val_acc : {max(history_p1.history["val_accuracy"]):.4f}')
print(f'Best val_precision : {max(history_p1.history["val_precision"]):.4f}')

# Reload best checkpoint so next phase starts from the best weights
with tfmot.quantization.keras.quantize_scope():
    model = tf.keras.models.load_model(base_save_path)
model.load_weights(best_ckpt_p1)

model.save(os.path.join(OUTPUT_DIR, f'{phase_name}_final_accuracy_{max(history_p1.history["val_accuracy"]):.4f}.keras'))
print(f'Saved → {phase_name}_final.keras')

del train_ds, val_ds
gc.collect()
# Out:
# === PHASE1_ALL_FROZEN ===
#   Frozen / trainable layers : 160 / 0
#   Trainable parameters      : 0
# Found 28709 files belonging to 7 classes.
# Found 7178 files belonging to 7 classes.
#
# [Class Weights] Dataset: fer13  |  Total samples: 28709
#   Class          Count    Weight
#   ------------------------------
#   angry           3995    1.0266  ██████
#   disgust          436    9.4066  ████████████████████████████████████████████████████████
#   fear            4097    1.0010  ██████
#   happy           7215    0.5684  ███
#   neutral         4965    0.8260  ████
#   sad             4830    0.8491  █████
#   surprise        3171    1.2934  ███████
# Epoch 1/15
# I0000 00:00:1780042883.207762     210 cuda_dnn.cc:529] Loaded cuDNN version 91002
#   5/898 [..............................] - ETA: 32s - loss: 2.2880 - accuracy: 0.1500 - precision: 0.1379       WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0330s vs `on_train_batch_end` time: 0.1237s). Check your callbacks.
# 898/898 [==============================] - ETA: 0s - loss: 2.4326 - accuracy: 0.1309 - precision: 0.1430
# Epoch 1: val_accuracy improved from -inf to 0.15032, saving model to /kaggle/working/qat_phases/phase1_all_frozen_best.keras
#   ep 001 | loss=2.4326 | acc=0.1309 | val_loss=2.1832 | val_acc=0.1503 | lr=7.00e-04
# 898/898 [==============================] - 90s 94ms/step - loss: 2.4326 - accuracy: 0.1309 - precision: 0.1430 - val_loss: 2.1832 - val_accuracy: 0.1503 - val_precision: 0.1385 - lr: 7.0000e-04
# Epoch 2/15
# 896/898 [============================>.] - ETA: 0s - loss: 2.4341 - accuracy: 0.1340 - precision: 0.1430
# Epoch 2: val_accuracy did not improve from 0.15032
#   ep 002 | loss=2.4340 | acc=0.1340 | val_loss=2.1832 | val_acc=0.1503 | lr=7.00e-04
# 898/898 [==============================] - 42s 46ms/step - loss: 2.4340 - accuracy: 0.1340 - precision: 0.1431 - val_loss: 2.1832 - val_accuracy: 0.1503 - val_precision: 0.1385 - lr: 7.0000e-04
# Epoch 3/15
# 897/898 [============================>.] - ETA: 0s - loss: 2.4328 - accuracy: 0.1304 - precision: 0.1457
# Epoch 3: val_accuracy did not improve from 0.15032
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0003499999875202775.
#   ep 003 | loss=2.4336 | acc=0.1304 | val_loss=2.1832 | val_acc=0.1503 | lr=3.50e-04
# 898/898 [==============================] - 41s 45ms/step - loss: 2.4336 - accuracy: 0.1304 - precision: 0.1457 - val_loss: 2.1832 - val_accuracy: 0.1503 - val_precision: 0.1385 - lr: 7.0000e-04
# Epoch 4/15
# 896/898 [============================>.] - ETA: 0s - loss: 2.4309 - accuracy: 0.1323 - precision: 0.1378
# Epoch 4: val_accuracy did not improve from 0.15032
#   ep 004 | loss=2.4309 | acc=0.1322 | val_loss=2.1832 | val_acc=0.1503 | lr=3.50e-04
# 898/898 [==============================] - 41s 45ms/step - loss: 2.4309 - accuracy: 0.1322 - precision: 0.1378 - val_loss: 2.1832 - val_accuracy: 0.1503 - val_precision: 0.1385 - lr: 3.5000e-04
# Epoch 5/15
# 896/898 [============================>.] - ETA: 0s - loss: 2.4238 - accuracy: 0.1315 - precision: 0.1491
# Epoch 5: val_accuracy did not improve from 0.15032
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.00017499999376013875.
#   ep 005 | loss=2.4244 | acc=0.1315 | val_loss=2.1832 | val_acc=0.1503 | lr=1.75e-04
# 898/898 [==============================] - 42s 47ms/step - loss: 2.4244 - accuracy: 0.1315 - precision: 0.1491 - val_loss: 2.1832 - val_accuracy: 0.1503 - val_precision: 0.1385 - lr: 3.5000e-04
# Epoch 5: early stopping
# Restoring model weights from the end of the best epoch: 1.
#
# Phase 1 done in 4.3 min
# Best val_acc : 0.1503
# Best val_precision : 0.1385
# Saved → phase1_all_frozen_final.keras
# 1677

# %% [markdown]
# ---
# ## Phase 2 — Top 90 layers frozen | FER-13 | lr = 7e-4
# Unfreeze the deeper layers of MobileNetV2. Lower LR prevents
# destroying the quantised scale ranges set in Phase 1.

# %%
phase_name, freeze_spec, dataset, lr, max_epochs, patience = PHASES[1]
print(f'=== {phase_name.upper()} ===')

model = apply_freeze(model, freeze_spec)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=lr, epsilon=1e-7),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=['accuracy',tf.keras.metrics.Precision(name='precision')],
)

train_ds, val_ds = get_datasets(dataset)
callbacks_p2, best_ckpt_p2 = build_callbacks(phase_name, patience, lr)
cw = compute_class_weights(dataset)

t0 = time.time()
history_p2 = model.fit(
    train_ds, validation_data=val_ds,
    epochs=max_epochs, callbacks=callbacks_p2, class_weight=cw,
)
print(f'\nPhase 2 done in {(time.time()-t0)/60:.1f} min')
print(f'Best val_acc : {max(history_p2.history["val_accuracy"]):.4f}')
print(f'Best val_precision : {max(history_p2.history["val_precision"]):.4f}')

with tfmot.quantization.keras.quantize_scope():
    model = tf.keras.models.load_model(base_save_path)
model.load_weights(best_ckpt_p2)

model.save(os.path.join(OUTPUT_DIR, f'{phase_name}_final_accuracy_{max(history_p2.history["val_accuracy"]):.4f}.keras'))
print(f'Saved → {phase_name}_final.keras')

del train_ds, val_ds
gc.collect()
# Out:
# === PHASE2_TOP90_FROZEN ===
#   Frozen / trainable layers : 90 / 70
#   Trainable parameters      : 2,773,511
# Found 28709 files belonging to 7 classes.
# Found 7178 files belonging to 7 classes.
#
# [Class Weights] Dataset: fer13  |  Total samples: 28709
#   Class          Count    Weight
#   ------------------------------
#   angry           3995    1.0266  ██████
#   disgust          436    9.4066  ████████████████████████████████████████████████████████
#   fear            4097    1.0010  ██████
#   happy           7215    0.5684  ███
#   neutral         4965    0.8260  ████
#   sad             4830    0.8491  █████
#   surprise        3171    1.2934  ███████
# Epoch 1/15
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1780043146.635900     207 service.cc:152] XLA service 0x7a8b3d234360 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1780043146.635972     207 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1780043146.872899     207 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 898/898 [==============================] - ETA: 0s - loss: 1.5889 - accuracy: 0.4500 - precision: 0.7197
# Epoch 1: val_accuracy improved from -inf to 0.02786, saving model to /kaggle/working/qat_phases/phase2_top90_frozen_best.keras
#   ep 001 | loss=1.5889 | acc=0.4500 | val_loss=5.0709 | val_acc=0.0279 | lr=7.00e-04
# 898/898 [==============================] - 68s 59ms/step - loss: 1.5889 - accuracy: 0.4500 - precision: 0.7197 - val_loss: 5.0709 - val_accuracy: 0.0279 - val_precision: 0.0248 - lr: 7.0000e-04
# Epoch 2/15
# 897/898 [============================>.] - ETA: 0s - loss: 1.4021 - accuracy: 0.5370 - precision: 0.7472
# Epoch 2: val_accuracy improved from 0.02786 to 0.23976, saving model to /kaggle/working/qat_phases/phase2_top90_frozen_best.keras
#   ep 002 | loss=1.4021 | acc=0.5370 | val_loss=2.6026 | val_acc=0.2398 | lr=7.00e-04
# 898/898 [==============================] - 52s 58ms/step - loss: 1.4021 - accuracy: 0.5370 - precision: 0.7473 - val_loss: 2.6026 - val_accuracy: 0.2398 - val_precision: 0.2726 - lr: 7.0000e-04
# Epoch 3/15
# 898/898 [==============================] - ETA: 0s - loss: 1.3261 - accuracy: 0.5747 - precision: 0.7641
# Epoch 3: val_accuracy improved from 0.23976 to 0.42839, saving model to /kaggle/working/qat_phases/phase2_top90_frozen_best.keras
#   ep 003 | loss=1.3261 | acc=0.5747 | val_loss=1.8071 | val_acc=0.4284 | lr=7.00e-04
# 898/898 [==============================] - 52s 58ms/step - loss: 1.3261 - accuracy: 0.5747 - precision: 0.7641 - val_loss: 1.8071 - val_accuracy: 0.4284 - val_precision: 0.5137 - lr: 7.0000e-04
# Epoch 4/15
# 897/898 [============================>.] - ETA: 0s - loss: 1.2934 - accuracy: 0.5863 - precision: 0.7745
# Epoch 4: val_accuracy improved from 0.42839 to 0.56910, saving model to /kaggle/working/qat_phases/phase2_top90_frozen_best.keras
#   ep 004 | loss=1.2934 | acc=0.5863 | val_loss=1.3525 | val_acc=0.5691 | lr=7.00e-04
# 898/898 [==============================] - 52s 58ms/step - loss: 1.2934 - accuracy: 0.5863 - precision: 0.7745 - val_loss: 1.3525 - val_accuracy: 0.5691 - val_precision: 0.7386 - lr: 7.0000e-04
# Epoch 5/15
# 898/898 [==============================] - ETA: 0s - loss: 1.2380 - accuracy: 0.6125 - precision: 0.7771
# Epoch 5: val_accuracy did not improve from 0.56910
#   ep 005 | loss=1.2380 | acc=0.6125 | val_loss=1.3859 | val_acc=0.5566 | lr=7.00e-04
# 898/898 [==============================] - 52s 57ms/step - loss: 1.2380 - accuracy: 0.6125 - precision: 0.7771 - val_loss: 1.3859 - val_accuracy: 0.5566 - val_precision: 0.7139 - lr: 7.0000e-04
# Epoch 6/15
# 897/898 [============================>.] - ETA: 0s - loss: 1.1944 - accuracy: 0.6298 - precision: 0.7809
# Epoch 6: val_accuracy did not improve from 0.56910
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0003499999875202775.
#   ep 006 | loss=1.1944 | acc=0.6298 | val_loss=1.3692 | val_acc=0.5485 | lr=3.50e-04
# 898/898 [==============================] - 51s 57ms/step - loss: 1.1944 - accuracy: 0.6298 - precision: 0.7809 - val_loss: 1.3692 - val_accuracy: 0.5485 - val_precision: 0.7277 - lr: 7.0000e-04
# Epoch 7/15
# 897/898 [============================>.] - ETA: 0s - loss: 1.0864 - accuracy: 0.6768 - precision: 0.8060
# Epoch 7: val_accuracy improved from 0.56910 to 0.58498, saving model to /kaggle/working/qat_phases/phase2_top90_frozen_best.keras
#   ep 007 | loss=1.0864 | acc=0.6768 | val_loss=1.3463 | val_acc=0.5850 | lr=3.50e-04
# 898/898 [==============================] - 52s 57ms/step - loss: 1.0864 - accuracy: 0.6768 - precision: 0.8060 - val_loss: 1.3463 - val_accuracy: 0.5850 - val_precision: 0.6954 - lr: 3.5000e-04
# Epoch 8/15
# 897/898 [============================>.] - ETA: 0s - loss: 1.0393 - accuracy: 0.7033 - precision: 0.8171
# Epoch 8: val_accuracy improved from 0.58498 to 0.61493, saving model to /kaggle/working/qat_phases/phase2_top90_frozen_best.keras
#   ep 008 | loss=1.0393 | acc=0.7034 | val_loss=1.2700 | val_acc=0.6149 | lr=3.50e-04
# 898/898 [==============================] - 53s 58ms/step - loss: 1.0393 - accuracy: 0.7034 - precision: 0.8171 - val_loss: 1.2700 - val_accuracy: 0.6149 - val_precision: 0.7415 - lr: 3.5000e-04
# Epoch 9/15
# 898/898 [==============================] - ETA: 0s - loss: 1.0009 - accuracy: 0.7213 - precision: 0.8245
# Epoch 9: val_accuracy improved from 0.61493 to 0.61563, saving model to /kaggle/working/qat_phases/phase2_top90_frozen_best.keras
#   ep 009 | loss=1.0009 | acc=0.7213 | val_loss=1.2438 | val_acc=0.6156 | lr=3.50e-04
# 898/898 [==============================] - 53s 58ms/step - loss: 1.0009 - accuracy: 0.7213 - precision: 0.8245 - val_loss: 1.2438 - val_accuracy: 0.6156 - val_precision: 0.7431 - lr: 3.5000e-04
# Epoch 10/15
# 897/898 [============================>.] - ETA: 0s - loss: 0.9651 - accuracy: 0.7371 - precision: 0.8363
# Epoch 10: val_accuracy improved from 0.61563 to 0.62162, saving model to /kaggle/working/qat_phases/phase2_top90_frozen_best.keras
#   ep 010 | loss=0.9651 | acc=0.7372 | val_loss=1.2454 | val_acc=0.6216 | lr=3.50e-04
# 898/898 [==============================] - 52s 58ms/step - loss: 0.9651 - accuracy: 0.7372 - precision: 0.8363 - val_loss: 1.2454 - val_accuracy: 0.6216 - val_precision: 0.7213 - lr: 3.5000e-04
# Epoch 11/15
# 897/898 [============================>.] - ETA: 0s - loss: 0.9454 - accuracy: 0.7504 - precision: 0.8407
# Epoch 11: val_accuracy did not improve from 0.62162
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.00017499999376013875.
#   ep 011 | loss=0.9454 | acc=0.7504 | val_loss=1.2952 | val_acc=0.6127 | lr=1.75e-04
# 898/898 [==============================] - 51s 56ms/step - loss: 0.9454 - accuracy: 0.7504 - precision: 0.8407 - val_loss: 1.2952 - val_accuracy: 0.6127 - val_precision: 0.6849 - lr: 3.5000e-04
# Epoch 12/15
# 897/898 [============================>.] - ETA: 0s - loss: 0.8662 - accuracy: 0.7917 - precision: 0.8653
# Epoch 12: val_accuracy improved from 0.62162 to 0.65255, saving model to /kaggle/working/qat_phases/phase2_top90_frozen_best.keras
#   ep 012 | loss=0.8663 | acc=0.7917 | val_loss=1.2045 | val_acc=0.6525 | lr=1.75e-04
# 898/898 [==============================] - 54s 59ms/step - loss: 0.8663 - accuracy: 0.7917 - precision: 0.8653 - val_loss: 1.2045 - val_accuracy: 0.6525 - val_precision: 0.7302 - lr: 1.7500e-04
# Epoch 13/15
# 898/898 [==============================] - ETA: 0s - loss: 0.8156 - accuracy: 0.8223 - precision: 0.8833
# Epoch 13: val_accuracy improved from 0.65255 to 0.65394, saving model to /kaggle/working/qat_phases/phase2_top90_frozen_best.keras
#   ep 013 | loss=0.8156 | acc=0.8223 | val_loss=1.2258 | val_acc=0.6539 | lr=1.75e-04
# 898/898 [==============================] - 53s 58ms/step - loss: 0.8156 - accuracy: 0.8223 - precision: 0.8833 - val_loss: 1.2258 - val_accuracy: 0.6539 - val_precision: 0.7087 - lr: 1.7500e-04
# Epoch 14/15
# 898/898 [==============================] - ETA: 0s - loss: 0.7740 - accuracy: 0.8430 - precision: 0.8957
# Epoch 14: val_accuracy did not improve from 0.65394
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 8.749999688006938e-05.
#   ep 014 | loss=0.7740 | acc=0.8430 | val_loss=1.2686 | val_acc=0.6449 | lr=8.75e-05
# 898/898 [==============================] - 51s 56ms/step - loss: 0.7740 - accuracy: 0.8430 - precision: 0.8957 - val_loss: 1.2686 - val_accuracy: 0.6449 - val_precision: 0.6959 - lr: 1.7500e-04
# Epoch 15/15
# 897/898 [============================>.] - ETA: 0s - loss: 0.7206 - accuracy: 0.8737 - precision: 0.9153
# Epoch 15: val_accuracy improved from 0.65394 to 0.66049, saving model to /kaggle/working/qat_phases/phase2_top90_frozen_best.keras
#   ep 015 | loss=0.7206 | acc=0.8737 | val_loss=1.2541 | val_acc=0.6605 | lr=8.75e-05
# 898/898 [==============================] - 53s 58ms/step - loss: 0.7206 - accuracy: 0.8737 - precision: 0.9152 - val_loss: 1.2541 - val_accuracy: 0.6605 - val_precision: 0.7010 - lr: 8.7500e-05
# Restoring model weights from the end of the best epoch: 12.
#
# Phase 2 done in 13.3 min
# Best val_acc : 0.6605
# Best val_precision : 0.7431
# Saved → phase2_top90_frozen_final.keras
# 1330

# %% [markdown]
# ---
# ## Phase 3 — Top 40 layers frozen | FER-13 | lr = 3e-6
# Fine-tune almost the entire network at a very low LR.
# Early stopping here is critical — watch val_accuracy closely.

# %%
phase_name, freeze_spec, dataset, lr, max_epochs, patience = PHASES[2]
print(f'=== {phase_name.upper()} ===')

model = apply_freeze(model, freeze_spec)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=lr, epsilon=1e-7),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=['accuracy',tf.keras.metrics.Precision(name='precision')],
)

train_ds, val_ds = get_datasets(dataset)
callbacks_p3, best_ckpt_p3 = build_callbacks(phase_name, patience, lr)
cw = compute_class_weights(dataset)

t0 = time.time()
history_p3 = model.fit(
    train_ds, validation_data=val_ds,
    epochs=max_epochs, callbacks=callbacks_p3, class_weight=cw,
)
print(f'\nPhase 3 done in {(time.time()-t0)/60:.1f} min')
print(f'Best val_acc : {max(history_p3.history["val_accuracy"]):.4f}')
print(f'Best val_precision : {max(history_p3.history["val_precision"]):.4f}')

with tfmot.quantization.keras.quantize_scope():
    model = tf.keras.models.load_model(base_save_path)
model.load_weights(best_ckpt_p3)

model.save(os.path.join(OUTPUT_DIR, f'{phase_name}_final_accuracy_{max(history_p3.history["val_accuracy"]):.4f}.keras'))
print(f'Saved → {phase_name}_final.keras')

del train_ds, val_ds
gc.collect()
# Out:
# === PHASE3_TOP40_FROZEN ===
#   Frozen / trainable layers : 40 / 120
#   Trainable parameters      : 2,978,823
# Found 28709 files belonging to 7 classes.
# Found 7178 files belonging to 7 classes.
#
# [Class Weights] Dataset: fer13  |  Total samples: 28709
#   Class          Count    Weight
#   ------------------------------
#   angry           3995    1.0266  ██████
#   disgust          436    9.4066  ████████████████████████████████████████████████████████
#   fear            4097    1.0010  ██████
#   happy           7215    0.5684  ███
#   neutral         4965    0.8260  ████
#   sad             4830    0.8491  █████
#   surprise        3171    1.2934  ███████
# Epoch 1/30
# 898/898 [==============================] - ETA: 0s - loss: 1.0785 - accuracy: 0.7242 - precision: 0.7803
# Epoch 1: val_accuracy improved from -inf to 0.63931, saving model to /kaggle/working/qat_phases/phase3_top40_frozen_best.keras
#   ep 001 | loss=1.0785 | acc=0.7242 | val_loss=1.2791 | val_acc=0.6393 | lr=3.00e-06
# 898/898 [==============================] - 82s 66ms/step - loss: 1.0785 - accuracy: 0.7242 - precision: 0.7803 - val_loss: 1.2791 - val_accuracy: 0.6393 - val_precision: 0.6954 - lr: 3.0000e-06
# Epoch 2/30
# 897/898 [============================>.] - ETA: 0s - loss: 0.9990 - accuracy: 0.7354 - precision: 0.7995
# Epoch 2: val_accuracy did not improve from 0.63931
#   ep 002 | loss=0.9990 | acc=0.7354 | val_loss=1.2765 | val_acc=0.6297 | lr=3.00e-06
# 898/898 [==============================] - 58s 65ms/step - loss: 0.9990 - accuracy: 0.7354 - precision: 0.7995 - val_loss: 1.2765 - val_accuracy: 0.6297 - val_precision: 0.6931 - lr: 3.0000e-06
# Epoch 3/30
# 897/898 [============================>.] - ETA: 0s - loss: 0.9621 - accuracy: 0.7471 - precision: 0.8155
# Epoch 3: val_accuracy did not improve from 0.63931
#   ep 003 | loss=0.9627 | acc=0.7471 | val_loss=1.2642 | val_acc=0.6342 | lr=3.00e-06
# 898/898 [==============================] - 58s 65ms/step - loss: 0.9627 - accuracy: 0.7471 - precision: 0.8154 - val_loss: 1.2642 - val_accuracy: 0.6342 - val_precision: 0.6978 - lr: 3.0000e-06
# Epoch 4/30
# 897/898 [============================>.] - ETA: 0s - loss: 0.9380 - accuracy: 0.7585 - precision: 0.8264
# Epoch 4: val_accuracy did not improve from 0.63931
#   ep 004 | loss=0.9380 | acc=0.7585 | val_loss=1.2542 | val_acc=0.6358 | lr=3.00e-06
# 898/898 [==============================] - 58s 65ms/step - loss: 0.9380 - accuracy: 0.7585 - precision: 0.8264 - val_loss: 1.2542 - val_accuracy: 0.6358 - val_precision: 0.7043 - lr: 3.0000e-06
# Epoch 5/30
# 897/898 [============================>.] - ETA: 0s - loss: 0.9157 - accuracy: 0.7687 - precision: 0.8370
# Epoch 5: val_accuracy improved from 0.63931 to 0.64168, saving model to /kaggle/working/qat_phases/phase3_top40_frozen_best.keras
#   ep 005 | loss=0.9158 | acc=0.7687 | val_loss=1.2445 | val_acc=0.6417 | lr=3.00e-06
# 898/898 [==============================] - 59s 65ms/step - loss: 0.9158 - accuracy: 0.7687 - precision: 0.8370 - val_loss: 1.2445 - val_accuracy: 0.6417 - val_precision: 0.7069 - lr: 3.0000e-06
# Epoch 6/30
# 897/898 [============================>.] - ETA: 0s - loss: 0.8978 - accuracy: 0.7764 - precision: 0.8446
# Epoch 6: val_accuracy improved from 0.64168 to 0.64419, saving model to /kaggle/working/qat_phases/phase3_top40_frozen_best.keras
#   ep 006 | loss=0.8980 | acc=0.7764 | val_loss=1.2394 | val_acc=0.6442 | lr=3.00e-06
# 898/898 [==============================] - 59s 65ms/step - loss: 0.8980 - accuracy: 0.7764 - precision: 0.8446 - val_loss: 1.2394 - val_accuracy: 0.6442 - val_precision: 0.7080 - lr: 3.0000e-06
# Epoch 7/30
# 897/898 [============================>.] - ETA: 0s - loss: 0.8814 - accuracy: 0.7861 - precision: 0.8509
# Epoch 7: val_accuracy improved from 0.64419 to 0.64572, saving model to /kaggle/working/qat_phases/phase3_top40_frozen_best.keras
#   ep 007 | loss=0.8814 | acc=0.7861 | val_loss=1.2363 | val_acc=0.6457 | lr=3.00e-06
# 898/898 [==============================] - 60s 66ms/step - loss: 0.8814 - accuracy: 0.7861 - precision: 0.8509 - val_loss: 1.2363 - val_accuracy: 0.6457 - val_precision: 0.7078 - lr: 3.0000e-06
# Epoch 8/30
# 897/898 [============================>.] - ETA: 0s - loss: 0.8715 - accuracy: 0.7887 - precision: 0.8547
# Epoch 8: val_accuracy improved from 0.64572 to 0.64781, saving model to /kaggle/working/qat_phases/phase3_top40_frozen_best.keras
#   ep 008 | loss=0.8715 | acc=0.7887 | val_loss=1.2340 | val_acc=0.6478 | lr=3.00e-06
# 898/898 [==============================] - 59s 66ms/step - loss: 0.8715 - accuracy: 0.7887 - precision: 0.8547 - val_loss: 1.2340 - val_accuracy: 0.6478 - val_precision: 0.7086 - lr: 3.0000e-06
# Epoch 9/30
# 897/898 [============================>.] - ETA: 0s - loss: 0.8555 - accuracy: 0.7969 - precision: 0.8594
# Epoch 9: val_accuracy did not improve from 0.64781
#   ep 009 | loss=0.8556 | acc=0.7969 | val_loss=1.2315 | val_acc=0.6474 | lr=3.00e-06
# 898/898 [==============================] - 59s 65ms/step - loss: 0.8556 - accuracy: 0.7969 - precision: 0.8594 - val_loss: 1.2315 - val_accuracy: 0.6474 - val_precision: 0.7084 - lr: 3.0000e-06
# Epoch 10/30
# 897/898 [============================>.] - ETA: 0s - loss: 0.8480 - accuracy: 0.8022 - precision: 0.8625
# Epoch 10: val_accuracy improved from 0.64781 to 0.65060, saving model to /kaggle/working/qat_phases/phase3_top40_frozen_best.keras
#   ep 010 | loss=0.8480 | acc=0.8022 | val_loss=1.2281 | val_acc=0.6506 | lr=3.00e-06
# 898/898 [==============================] - 59s 65ms/step - loss: 0.8480 - accuracy: 0.8022 - precision: 0.8625 - val_loss: 1.2281 - val_accuracy: 0.6506 - val_precision: 0.7096 - lr: 3.0000e-06
# Epoch 11/30
# 897/898 [============================>.] - ETA: 0s - loss: 0.8328 - accuracy: 0.8077 - precision: 0.8687
# Epoch 11: val_accuracy improved from 0.65060 to 0.65269, saving model to /kaggle/working/qat_phases/phase3_top40_frozen_best.keras
#   ep 011 | loss=0.8327 | acc=0.8077 | val_loss=1.2264 | val_acc=0.6527 | lr=3.00e-06
# 898/898 [==============================] - 59s 66ms/step - loss: 0.8327 - accuracy: 0.8077 - precision: 0.8687 - val_loss: 1.2264 - val_accuracy: 0.6527 - val_precision: 0.7135 - lr: 3.0000e-06
# Epoch 12/30
# 897/898 [============================>.] - ETA: 0s - loss: 0.8302 - accuracy: 0.8105 - precision: 0.8693
# Epoch 12: val_accuracy did not improve from 0.65269
#   ep 012 | loss=0.8303 | acc=0.8104 | val_loss=1.2256 | val_acc=0.6527 | lr=3.00e-06
# 898/898 [==============================] - 59s 65ms/step - loss: 0.8303 - accuracy: 0.8104 - precision: 0.8693 - val_loss: 1.2256 - val_accuracy: 0.6527 - val_precision: 0.7138 - lr: 3.0000e-06
# Epoch 13/30
# 897/898 [============================>.] - ETA: 0s - loss: 0.8175 - accuracy: 0.8161 - precision: 0.8764
# Epoch 13: val_accuracy improved from 0.65269 to 0.65297, saving model to /kaggle/working/qat_phases/phase3_top40_frozen_best.keras
#   ep 013 | loss=0.8174 | acc=0.8161 | val_loss=1.2239 | val_acc=0.6530 | lr=3.00e-06
# 898/898 [==============================] - 59s 65ms/step - loss: 0.8174 - accuracy: 0.8161 - precision: 0.8764 - val_loss: 1.2239 - val_accuracy: 0.6530 - val_precision: 0.7142 - lr: 3.0000e-06
# Epoch 14/30
# 897/898 [============================>.] - ETA: 0s - loss: 0.8124 - accuracy: 0.8189 - precision: 0.8782
# Epoch 14: val_accuracy improved from 0.65297 to 0.65492, saving model to /kaggle/working/qat_phases/phase3_top40_frozen_best.keras
#   ep 014 | loss=0.8123 | acc=0.8189 | val_loss=1.2235 | val_acc=0.6549 | lr=3.00e-06
# 898/898 [==============================] - 59s 65ms/step - loss: 0.8123 - accuracy: 0.8189 - precision: 0.8782 - val_loss: 1.2235 - val_accuracy: 0.6549 - val_precision: 0.7139 - lr: 3.0000e-06
# Epoch 15/30
# 897/898 [============================>.] - ETA: 0s - loss: 0.8080 - accuracy: 0.8201 - precision: 0.8778
# Epoch 15: val_accuracy did not improve from 0.65492
#   ep 015 | loss=0.8080 | acc=0.8201 | val_loss=1.2260 | val_acc=0.6531 | lr=3.00e-06
# 898/898 [==============================] - 58s 65ms/step - loss: 0.8080 - accuracy: 0.8201 - precision: 0.8778 - val_loss: 1.2260 - val_accuracy: 0.6531 - val_precision: 0.7134 - lr: 3.0000e-06
# Epoch 16/30
# 897/898 [============================>.] - ETA: 0s - loss: 0.8018 - accuracy: 0.8254 - precision: 0.8817
# Epoch 16: val_accuracy did not improve from 0.65492
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1.500000053056283e-06.
#   ep 016 | loss=0.8018 | acc=0.8254 | val_loss=1.2254 | val_acc=0.6546 | lr=1.50e-06
# 898/898 [==============================] - 58s 64ms/step - loss: 0.8018 - accuracy: 0.8254 - precision: 0.8817 - val_loss: 1.2254 - val_accuracy: 0.6546 - val_precision: 0.7145 - lr: 3.0000e-06
# Epoch 17/30
# 897/898 [============================>.] - ETA: 0s - loss: 0.7989 - accuracy: 0.8276 - precision: 0.8834
# Epoch 17: val_accuracy improved from 0.65492 to 0.65520, saving model to /kaggle/working/qat_phases/phase3_top40_frozen_best.keras
#   ep 017 | loss=0.7990 | acc=0.8275 | val_loss=1.2261 | val_acc=0.6552 | lr=1.50e-06
# 898/898 [==============================] - 59s 66ms/step - loss: 0.7990 - accuracy: 0.8275 - precision: 0.8833 - val_loss: 1.2261 - val_accuracy: 0.6552 - val_precision: 0.7138 - lr: 1.5000e-06
# Epoch 18/30
# 897/898 [============================>.] - ETA: 0s - loss: 0.7913 - accuracy: 0.8308 - precision: 0.8857
# Epoch 18: val_accuracy improved from 0.65520 to 0.65561, saving model to /kaggle/working/qat_phases/phase3_top40_frozen_best.keras
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 7.500000265281415e-07.
#   ep 018 | loss=0.7912 | acc=0.8308 | val_loss=1.2267 | val_acc=0.6556 | lr=7.50e-07
# 898/898 [==============================] - 59s 65ms/step - loss: 0.7912 - accuracy: 0.8308 - precision: 0.8857 - val_loss: 1.2267 - val_accuracy: 0.6556 - val_precision: 0.7130 - lr: 1.5000e-06
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 13.
#
# Phase 3 done in 18.0 min
# Best val_acc : 0.6556
# Best val_precision : 0.7145
# Saved → phase3_top40_frozen_final.keras
# 1437

# %% [markdown]
# ---
# ## Phase 4 — Top 40 layers frozen | RAF-DB | lr = 3e-6
# Domain adaptation from FER-13 to RAF-DB at ultra-low LR.
# The quantisation ranges are stable — this phase just nudges
# the weights toward the RAF-DB distribution.

# %%
phase_name, freeze_spec, dataset, lr, max_epochs, patience = PHASES[3]
print(f'=== {phase_name.upper()} ===')

model = apply_freeze(model, freeze_spec)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=lr, epsilon=1e-7),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=['accuracy',tf.keras.metrics.Precision(name='precision')],
)

train_ds, val_ds = get_datasets(dataset)
callbacks_p4, best_ckpt_p4 = build_callbacks(phase_name, patience, lr)
cw = compute_class_weights(dataset)

t0 = time.time()
history_p4 = model.fit(
    train_ds, validation_data=val_ds,
    epochs=max_epochs, callbacks=callbacks_p4, class_weight=cw
)
print(f'\nPhase 4 done in {(time.time()-t0)/60:.1f} min')
print(f'Best val_acc : {max(history_p4.history["val_accuracy"]):.4f}')
print(f'Best val_precision : {max(history_p4.history["val_precision"]):.4f}')

with tfmot.quantization.keras.quantize_scope():
    model = tf.keras.models.load_model(base_save_path)
model.load_weights(best_ckpt_p4)

model.save(os.path.join(OUTPUT_DIR, f'{phase_name}_final_accuracy_{max(history_p4.history["val_accuracy"]):.4f}.keras'))
print(f'Saved → {phase_name}_final.keras')

del train_ds, val_ds
gc.collect()
# Out:
# === PHASE4_RAFDB ===
#   Frozen / trainable layers : 40 / 120
#   Trainable parameters      : 2,978,823
# Found 12271 files belonging to 7 classes.
# Found 3068 files belonging to 7 classes.
#
# [Class Weights] Dataset: rafdb  |  Total samples: 12271
#   Class          Count    Weight
#   ------------------------------
#   1               1290    1.3589  ████████
#   2                281    6.2384  █████████████████████████████████████
#   3                717    2.4449  ██████████████
#   4               4772    0.3674  ██
#   5               1982    0.8845  █████
#   6                705    2.4865  ██████████████
#   7               2524    0.6945  ████
# Epoch 1/75
# 384/384 [==============================] - ETA: 0s - loss: 1.2105 - accuracy: 0.7658 - precision: 0.8348
# Epoch 1: val_accuracy improved from -inf to 0.74804, saving model to /kaggle/working/qat_phases/phase4_rafdb_best.keras
#   ep 001 | loss=1.2105 | acc=0.7658 | val_loss=1.0380 | val_acc=0.7480 | lr=3.00e-06
# 384/384 [==============================] - 50s 69ms/step - loss: 1.2105 - accuracy: 0.7658 - precision: 0.8348 - val_loss: 1.0380 - val_accuracy: 0.7480 - val_precision: 0.8061 - lr: 3.0000e-06
# Epoch 2/75
# 383/384 [============================>.] - ETA: 0s - loss: 1.1607 - accuracy: 0.7819 - precision: 0.8457
# Epoch 2: val_accuracy improved from 0.74804 to 0.75456, saving model to /kaggle/working/qat_phases/phase4_rafdb_best.keras
#   ep 002 | loss=1.1603 | acc=0.7818 | val_loss=1.0264 | val_acc=0.7546 | lr=3.00e-06
# 384/384 [==============================] - 26s 68ms/step - loss: 1.1603 - accuracy: 0.7818 - precision: 0.8456 - val_loss: 1.0264 - val_accuracy: 0.7546 - val_precision: 0.8107 - lr: 3.0000e-06
# Epoch 3/75
# 383/384 [============================>.] - ETA: 0s - loss: 1.1416 - accuracy: 0.7887 - precision: 0.8574
# Epoch 3: val_accuracy did not improve from 0.75456
#   ep 003 | loss=1.1412 | acc=0.7885 | val_loss=1.0145 | val_acc=0.7546 | lr=3.00e-06
# 384/384 [==============================] - 25s 65ms/step - loss: 1.1412 - accuracy: 0.7885 - precision: 0.8574 - val_loss: 1.0145 - val_accuracy: 0.7546 - val_precision: 0.8153 - lr: 3.0000e-06
# Epoch 4/75
#   4/384 [..............................] - ETA: 25s - loss: 1.1777 - accuracy: 0.7734 - precision: 0.8288
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_120/3182984520.py in <cell line: 0>()
#      15
#      16 t0 = time.time()
# ---> 17 history_p4 = model.fit(
#      18     train_ds, validation_data=val_ds,
#      19     epochs=max_epochs, callbacks=callbacks_p4, class_weight=cw
#
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1802                         ):
#    1803                             callbacks.on_train_batch_begin(step)
# -> 1804                             tmp_logs = self.train_function(iterator)
#    1805                             if data_handler.should_sync:
#    1806                                 context.async_wait()
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     831
#     832       with OptionalXlaContext(self._jit_compile):
# --> 833         result = self._call(*args, **kwds)
#     834
#     835       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     867       # In this case we have created variables on the first call, so we run the
#     868       # defunned version which is guaranteed to never create variables.
# --> 869       return tracing_compilation.call_function(
#     870           args, kwds, self._no_variable_creation_config
#     871       )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1320         and executing_eagerly):
#    1321       # No tape is watching; skip to running the function.
# -> 1322       return self._inference_function.call_preflattened(args)
#    1323     forward_backward = self._select_forward_and_backward_functions(
#    1324         args,
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1686     cancellation_context = cancellation.context()
#    1687     if cancellation_context is None:
# -> 1688       outputs = execute.execute(
#    1689           name.decode("utf-8"),
#    1690           num_outputs=num_outputs,
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# ---
# ## Phase 5 — Top 40 layers frozen | AFD-Dataset | lr = 5e-6
# Domain adaptation from RAF-DB at ultra-low LR.
# The quantisation ranges are stable — this phase just nudges
# the weights toward the AFD distribution.

# %%
phase_name, freeze_spec, dataset, lr, max_epochs, patience = PHASES[4]
print(f'=== {phase_name.upper()} ===')

model = apply_freeze(model, freeze_spec)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=lr, epsilon=1e-7),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=['accuracy',tf.keras.metrics.Precision(name='precision')],
)

train_ds, val_ds = get_datasets(dataset)
callbacks_p5, best_ckpt_p5 = build_callbacks(phase_name, patience, lr)
cw = compute_class_weights(dataset)

t0 = time.time()
history_p5 = model.fit(
    train_ds, validation_data=val_ds,
    epochs=max_epochs, callbacks=callbacks_p5, class_weight=cw,
)
print(f'\nPhase 5 done in {(time.time()-t0)/60:.1f} min')
print(f'Best val_acc : {max(history_p5.history["val_accuracy"]):.4f}')
print(f'Best val_precision : {max(history_p5.history["val_precision"]):.4f}')

with tfmot.quantization.keras.quantize_scope():
    model = tf.keras.models.load_model(base_save_path)
model.load_weights(best_ckpt_p5)

model.save(os.path.join(OUTPUT_DIR, f'{phase_name}_final_accuracy_{max(history_p5.history["val_accuracy"]):.4f}.keras'))
print(f'Saved → {phase_name}_final.keras')

del train_ds, val_ds
gc.collect()

# %% [markdown]
# # Model Evaluation
#
# ## Training Curves — All Phases

# %%
all_histories = [
    ('Phase 1\nFER-13 7e-4', history_p1),
    ('Phase 2\nFER-13 7e-4', history_p2),
    ('Phase 3\nFER-13 3e-6', history_p3),
    ('Phase 4\nRAF-DB 3e-6', history_p4),
    ('Phase 5\nAFD-DB 5e-6', history_p5),
]

fig, axes = plt.subplots(2, 5, figsize=(18, 8))
fig.suptitle('MobileNetV2 QAT — Training Curves per Phase', fontsize=13, y=1.01)

for col, (title, hist) in enumerate(all_histories):
    epochs = range(1, len(hist.history['accuracy']) + 1)

    # Accuracy
    axes[0, col].plot(epochs, hist.history['accuracy'],     label='train', marker='o', ms=3)
    axes[0, col].plot(epochs, hist.history['val_accuracy'], label='val',   marker='s', ms=3, linestyle='--')
    axes[0, col].set_title(title, fontsize=10)
    axes[0, col].set_ylabel('Accuracy' if col == 0 else '')
    axes[0, col].set_ylim(0, 1)
    axes[0, col].legend(fontsize=8)
    axes[0, col].grid(True, alpha=0.3)

    # Loss
    axes[1, col].plot(epochs, hist.history['loss'],     label='train', marker='o', ms=3)
    axes[1, col].plot(epochs, hist.history['val_loss'], label='val',   marker='s', ms=3, linestyle='--')
    axes[1, col].set_ylabel('Loss' if col == 0 else '')
    axes[1, col].set_xlabel('Epoch')
    axes[1, col].legend(fontsize=8)
    axes[1, col].grid(True, alpha=0.3)

plt.tight_layout()
plot_path = os.path.join(OUTPUT_DIR, 'training_curves.png')
plt.savefig(plot_path, dpi=120, bbox_inches='tight')
plt.show()
print(f'Plot saved → {plot_path}')
# Out:
# Plot saved → /kaggle/working/qat_phases/training_curves.png

# %% [markdown]
# ## Confusion Matrix

# %%
EMOTION_LABELS = ['Angry', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise']

phase_models = [
    ('Phase 1\nFER-13 7e-4',  os.path.join(OUTPUT_DIR, 'phase1_all_frozen_final_accuracy_0.1503.keras'),   'fer13'),
    ('Phase 2\nFER-13 7e-4',  os.path.join(OUTPUT_DIR, 'phase2_top90_frozen_final_accuracy_0.6605.keras'),  'fer13'),
    ('Phase 3\nFER-13 3e-6',  os.path.join(OUTPUT_DIR, 'phase3_top40_frozen_final_accuracy_0.6556.keras'),  'fer13'),
    ('Phase 4\nRAF-DB 3e-6',  os.path.join(OUTPUT_DIR, 'phase4_rafdb_final_accuracy_0.7435.keras'),         'rafdb'),
    ('Phase 5\nAFD-DB 5e-6',  os.path.join(OUTPUT_DIR, 'phase5_afd_final_accuracy_0.8988.keras'),         'afd'),
]

fig, axes = plt.subplots(1, 5, figsize=(28, 5))
fig.suptitle('MobileNetV2 QAT — Confusion Matrix per Phase (% of true class)', fontsize=13, y=1.02)

for col, (title, ckpt_path, dataset_name) in enumerate(phase_models):

    # ── Load phase model ──────────────────────────────────────────────
    with tfmot.quantization.keras.quantize_scope():
        phase_model = tf.keras.models.load_model(ckpt_path)

    # ── Get val dataset ───────────────────────────────────────────────
    _, val_ds = get_datasets(dataset_name)

    # ── Collect true labels + predictions ────────────────────────────
    y_true, y_pred = [], []
    for images, labels in val_ds:
        preds = phase_model.predict(images, verbose=0)
        y_true.extend(np.argmax(labels.numpy(), axis=1))
        y_pred.extend(np.argmax(preds, axis=1))

    # ── Confusion matrix normalised to % of true class (row-wise) ────
    cm = confusion_matrix(y_true, y_pred)
    cm_pct = (cm.astype(float) / cm.sum(axis=1, keepdims=True)) * 100

    # ── Plot ──────────────────────────────────────────────────────────
    sns.heatmap(
        cm_pct,
        ax=axes[col],
        annot=True,
        fmt='.1f',            # one decimal place e.g. 87.3
        cmap='Blues',
        vmin=0, vmax=100,
        xticklabels=EMOTION_LABELS,
        yticklabels=EMOTION_LABELS,
        linewidths=0.4,
        cbar=col == 4,        # only show colorbar on last plot
        annot_kws={'size': 7},
    )
    axes[col].set_title(title, fontsize=10)
    axes[col].set_xlabel('Predicted', fontsize=8)
    axes[col].set_ylabel('True' if col == 0 else '', fontsize=8)
    axes[col].tick_params(axis='x', rotation=45, labelsize=7)
    axes[col].tick_params(axis='y', rotation=0,  labelsize=7)

    # ── Print per-phase summary ───────────────────────────────────────
    overall_acc = np.diag(cm).sum() / cm.sum() * 100
    print(f'{title.replace(chr(10), " "):25s} — overall acc: {overall_acc:.1f}%')

    del phase_model
    gc.collect()

plt.tight_layout()
cm_path = os.path.join(OUTPUT_DIR, 'V2_9th_trial_confusion_matrices.png')
plt.savefig(cm_path, dpi=120, bbox_inches='tight')
plt.show()
print(f'Saved → {cm_path}')
# Out:
# Found 28709 files belonging to 7 classes.
# Found 7178 files belonging to 7 classes.
# Phase 1 FER-13 7e-4       — overall acc: 15.0%
# Found 28709 files belonging to 7 classes.
# Found 7178 files belonging to 7 classes.
# Phase 2 FER-13 7e-4       — overall acc: 66.0%
# Found 28709 files belonging to 7 classes.
# Found 7178 files belonging to 7 classes.
# Phase 3 FER-13 3e-6       — overall acc: 65.6%
# Found 12271 files belonging to 7 classes.
# Found 3068 files belonging to 7 classes.
# Phase 4 RAF-DB 3e-6       — overall acc: 74.3%
# Found 672 files belonging to 7 classes.
# Found 168 files belonging to 7 classes.
# Phase 5 AFD-DB 5e-6       — overall acc: 89.9%
# Saved → /kaggle/working/qat_phases/10th_trial_confusion_matrices.png

# %% [markdown]
# # TFLite INT8 Conversion

# %%
print('Converting QAT model → TFLite INT8 ...')

converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
# QAT already calibrated activation ranges — no representative
# dataset needed for INT8 conversion
tflite_bytes = converter.convert()

tflite_path = os.path.join(OUTPUT_DIR, 'final_qat_int8.tflite')
with open(tflite_path, 'wb') as f:
    f.write(tflite_bytes)

print(f'Saved → {tflite_path}')
print(f'File size : {len(tflite_bytes)/1024:.1f} KB')
# Out:
# Converting QAT model → TFLite INT8 ...
# INFO:tensorflow:Assets written to: /tmp/tmpvaien14u/assets
# INFO:tensorflow:Assets written to: /tmp/tmpvaien14u/assets
# Saved → /kaggle/working/qat_phases/final_qat_int8.tflite
# File size : 3220.5 KB
# W0000 00:00:1780047478.105893     120 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1780047478.105949     120 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# I0000 00:00:1780047478.328965     120 mlir_graph_optimization_pass.cc:425] MLIR V1 optimization pass is not enabled

# %% [markdown]
# ## TFLite Smoke Testing

# %%
interpreter = tf.lite.Interpreter(model_path=tflite_path)
interpreter.allocate_tensors()

inp_detail  = interpreter.get_input_details()[0]
out_detail  = interpreter.get_output_details()[0]
dummy_input = np.random.rand(1, *IMAGE_SIZE, CHANNELS).astype(np.float32)

interpreter.set_tensor(inp_detail['index'], dummy_input)
interpreter.invoke()
preds = interpreter.get_tensor(out_detail['index'])

EMOTION_LABELS = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']
print(f'Input  shape : {inp_detail["shape"]}  dtype: {inp_detail["dtype"]}')
print(f'Output shape : {out_detail["shape"]}  dtype: {out_detail["dtype"]}')
print(f'Predicted class : {EMOTION_LABELS[np.argmax(preds)]} ({preds.max():.3f})')
print('TFLite INT8 inference OK ✓')
# Out:
# Input  shape : [  1 224 224   3]  dtype: <class 'numpy.float32'>
# Output shape : [1 7]  dtype: <class 'numpy.float32'>
# Predicted class : neutral (0.313)
# TFLite INT8 inference OK ✓
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.

# %%
def evaluate_tflite(tflite_path, dataset_name):
    """
    Run full evaluation on the TFLite INT8 model.
    Reports accuracy, precision, recall, F1 per class + overall.
    """

    # ── Load TFLite model ─────────────────────────────────────────────
    interpreter = tf.lite.Interpreter(model_path=tflite_path)
    interpreter.allocate_tensors()
    inp_detail = interpreter.get_input_details()[0]
    out_detail = interpreter.get_output_details()[0]

    # ── Run inference on full val set ─────────────────────────────────
    _, val_ds = get_datasets(dataset_name)

    y_true, y_pred, y_prob = [], [], []
    for images, labels in val_ds:
        for i in range(len(images)):
            img = images[i].numpy()[np.newaxis].astype(np.float32)  # (1, 224, 224, 3)
            interpreter.set_tensor(inp_detail['index'], img)
            interpreter.invoke()
            prob = interpreter.get_tensor(out_detail['index'])[0]   # (7,)
            y_true.append(np.argmax(labels[i].numpy()))
            y_pred.append(np.argmax(prob))
            y_prob.append(prob)

    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    y_prob = np.array(y_prob)

    # ── Overall metrics ───────────────────────────────────────────────
    overall_acc = (y_true == y_pred).mean() * 100
    print(f'\n{"═"*55}')
    print(f'  TFLite INT8 Evaluation — {dataset_name.upper()} val set')
    print(f'{"═"*55}')
    print(f'  Overall Accuracy : {overall_acc:.2f}%')

    # ── Per-class report ──────────────────────────────────────────────
    report = classification_report(
        y_true, y_pred,
        target_names=EMOTION_LABELS,
        digits=4,
        output_dict=True,
    )

    # Print formatted table
    print(f'\n  {"Class":<12} {"Precision":>10} {"Recall":>10} {"F1":>10} {"Support":>10}')
    print(f'  {"─"*52}')
    for label in EMOTION_LABELS:
        r = report[label]
        print(
            f'  {label:<12}'
            f'  {r["precision"]*100:>8.2f}%'
            f'  {r["recall"]*100:>8.2f}%'
            f'  {r["f1-score"]*100:>8.2f}%'
            f'  {int(r["support"]):>9}'
        )
    print(f'  {"─"*52}')
    macro = report['macro avg']
    print(
        f'  {"Macro avg":<12}'
        f'  {macro["precision"]*100:>8.2f}%'
        f'  {macro["recall"]*100:>8.2f}%'
        f'  {macro["f1-score"]*100:>8.2f}%'
    )
    weighted = report['weighted avg']
    print(
        f'  {"Weighted avg":<12}'
        f'  {weighted["precision"]*100:>8.2f}%'
        f'  {weighted["recall"]*100:>8.2f}%'
        f'  {weighted["f1-score"]*100:>8.2f}%'
    )

    # ── Confusion matrix ──────────────────────────────────────────────
    cm = confusion_matrix(y_true, y_pred)
    cm_pct = (cm.astype(float) / cm.sum(axis=1, keepdims=True)) * 100

    fig, ax = plt.subplots(figsize=(8, 6))
    sns.heatmap(
        cm_pct, ax=ax,
        annot=True, fmt='.1f', cmap='Blues',
        vmin=0, vmax=100,
        xticklabels=EMOTION_LABELS,
        yticklabels=EMOTION_LABELS,
        linewidths=0.4,
        annot_kws={'size': 9},
    )
    ax.set_title(f'TFLite INT8 — Confusion Matrix (% of true class)\n{dataset_name.upper()} val set', fontsize=11)
    ax.set_xlabel('Predicted', fontsize=10)
    ax.set_ylabel('True', fontsize=10)
    ax.tick_params(axis='x', rotation=45, labelsize=9)
    ax.tick_params(axis='y', rotation=0,  labelsize=9)
    plt.tight_layout()

    cm_path = os.path.join(OUTPUT_DIR, f'{dataset_name}_tflite_confusion_matrix.png')
    plt.savefig(cm_path, dpi=120, bbox_inches='tight')
    plt.show()
    print(f'\nConfusion matrix saved → {cm_path}')

    return report


# ── Run it ────────────────────────────────────────────────────────────
tflite_report = evaluate_tflite(tflite_path, dataset_name='fer13')
tflite_report = evaluate_tflite(tflite_path, dataset_name='rafdb')
tflite_report = evaluate_tflite(tflite_path, dataset_name='afd')
# Out:
# Found 28709 files belonging to 7 classes.
# Found 7178 files belonging to 7 classes.
#
# ═══════════════════════════════════════════════════════
#   TFLite INT8 Evaluation — FER13 val set
# ═══════════════════════════════════════════════════════
#   Overall Accuracy : 59.61%
#
#   Class         Precision     Recall         F1    Support
#   ────────────────────────────────────────────────────
#   angry            64.52%     33.40%     44.02%        958
#   disgust          19.58%     75.68%     31.11%        111
#   fear             47.03%     30.96%     37.34%       1024
#   happy            81.26%     85.57%     83.36%       1774
#   neutral          53.10%     54.91%     53.99%       1233
#   sad              48.80%     55.49%     51.93%       1247
#   surprise         65.91%     80.75%     72.58%        831
#   ────────────────────────────────────────────────────
#   Macro avg        54.32%     59.54%     53.48%
#   Weighted avg     60.94%     59.61%     58.98%
# Confusion matrix saved → /kaggle/working/qat_phases/fer13_tflite_confusion_matrix.png
# Found 12271 files belonging to 7 classes.
# Found 3068 files belonging to 7 classes.
#
# ═══════════════════════════════════════════════════════
#   TFLite INT8 Evaluation — RAFDB val set
# ═══════════════════════════════════════════════════════
#   Overall Accuracy : 75.13%
#
#   Class         Precision     Recall         F1    Support
#   ────────────────────────────────────────────────────
#   angry            69.12%     58.02%     63.09%        162
#   disgust          40.48%     53.12%     45.95%        160
#   fear             32.50%     52.70%     40.21%         74
#   happy            94.01%     83.46%     88.42%       1185
#   neutral          70.99%     75.59%     73.22%        680
#   sad              64.72%     80.96%     71.93%        478
#   surprise         86.40%     59.88%     70.74%        329
#   ────────────────────────────────────────────────────
#   Macro avg        65.46%     66.25%     64.79%
#   Weighted avg     77.94%     75.13%     75.87%
# Confusion matrix saved → /kaggle/working/qat_phases/rafdb_tflite_confusion_matrix.png
# Found 672 files belonging to 7 classes.
# Found 168 files belonging to 7 classes.
#
# ═══════════════════════════════════════════════════════
#   TFLite INT8 Evaluation — AFD val set
# ═══════════════════════════════════════════════════════
#   Overall Accuracy : 83.33%
#
#   Class         Precision     Recall         F1    Support
#   ────────────────────────────────────────────────────
#   angry           100.00%     37.50%     54.55%         24
#   disgust          54.55%    100.00%     70.59%         24
#   fear             95.00%     79.17%     86.36%         24
#   happy           100.00%    100.00%    100.00%         24
#   neutral         100.00%     83.33%     90.91%         24
#   sad              91.30%     87.50%     89.36%         24
#   surprise         82.14%     95.83%     88.46%         24
#   ────────────────────────────────────────────────────
#   Macro avg        89.00%     83.33%     82.89%
#   Weighted avg     89.00%     83.33%     82.89%
# Confusion matrix saved → /kaggle/working/qat_phases/afd_tflite_confusion_matrix.png

# %% [markdown]
# # Model Save and Export

# %%
# Only put in the model file name
model.export("phase5_afd_final_accuracy_0.8988")

print("Model ready to be zip")
# Out:
# INFO:tensorflow:Assets written to: phase5_afd_final_accuracy_0.8988/assets
# INFO:tensorflow:Assets written to: phase5_afd_final_accuracy_0.8988/assets
# Saved artifact at 'phase5_afd_final_accuracy_0.8988'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_1')
# Output Type:
#   TensorSpec(shape=(None, 7), dtype=tf.float32, name=None)
# Captures:
#   134739629685648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134739629684688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134739629684880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134739629684496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134739629683920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134739629685264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134739629686416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134739629685840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738964444944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738964446288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738964444560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738964445712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738964445136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738964446480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831114512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831115088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831115472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831116048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831116240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831115664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831116432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831114896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831116624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831114704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831115856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134739629686224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831117968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831117776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831116816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831117008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831118352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831118928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831118544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831117392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831117200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831119312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831119120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831119504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831118736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831118160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831120272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831120848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831120464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831119696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831119888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831121232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831121808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831121424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831120656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831115280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831122192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831122000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831122384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831121616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831120080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831123152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831123728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831123344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831122576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831122768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831124112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831124688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831124304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831123536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831122960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831125072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831124880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831125264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831124496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831123920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831126032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831126608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831126224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831125456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831125648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831126992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831127568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831127184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831126416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831121040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831127952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831127760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831128144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831127376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831126800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831128912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831129488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831129104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831128336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831128528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831129872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831130448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831130064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831129296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831125840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831130256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831128720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738831129680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727240528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727240336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727240912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727241488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727241104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727239760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727239952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727241872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727242448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727242064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727241296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727240720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727242832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727242640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727243024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727242256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727241680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727243792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727244368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727243984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727243216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727243408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727244752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727245328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727244944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727244176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727240144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727245712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727245520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727245904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727245136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727244560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727246672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727247248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727246864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727246096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727246288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727247632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727248208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727247824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727247056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727243600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727248592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727248400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727248784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727248016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727247440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727249552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727250128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727249744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727248976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727249168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727250512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727251088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727250704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727249936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727246480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727251472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727251280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727251664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727250896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727250320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727252432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727253008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727252624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727251856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727252048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727253392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727253968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727253584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727252816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727252240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727254352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727254160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727254544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727253776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727253200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727255312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727255888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727255504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727254736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727254928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727255696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727255120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738727249360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860835664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860835472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860836048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860835856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860836240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860834896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860835088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860837008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860837584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860837200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860836432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860836624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860837968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860838544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860838160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860837392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860835280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860838928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860838736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860839120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860838352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860836816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860839888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860840464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860840080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860839312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860839504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860840848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860841424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860841040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860840272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860839696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860841808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860841616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860842000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860841232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860840656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860842768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860843344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860842960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860842192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860842384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860843728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860844304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860843920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860843152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860837776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860844688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860844496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860844880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860844112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860843536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860845648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860846224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860845840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860845072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860845264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860846608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860847184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860846800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860846032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860842576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860847568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860847376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860847760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860846992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860846416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860848528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860849104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860848720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860847952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860848144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860849488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860850064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860849680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860848912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860848336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860850448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860851024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860845456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860849296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860849872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134738860850256: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Model ready to be zip

# %%
import shutil

# put in the path of the new exported model folder
shutil.make_archive("/kaggle/working/phase5_afd_final_accuracy_0.8988", 'zip', "/kaggle/working/phase5_afd_final_accuracy_0.8988")
# Out:
# '/kaggle/working/phase5_afd_final_accuracy_0.8988.zip'

# %% [markdown]
# # Output Summary

# %%
print('\n── All phase results ──────────────────────────────────')
for label, hist in [
    ('Phase 1 (FER-13 7e-4)', history_p1),
    ('Phase 2 (FER-13 7e-4)', history_p2),
    ('Phase 3 (FER-13 3e-6)', history_p3),
    ('Phase 4 (RAF-DB 3e-6)', history_p4),
    ('Phase 5 (AFD-DB 5e-6)', history_p5),
]:
    best_acc       = max(hist.history['val_accuracy'])
    best_loss      = min(hist.history['val_loss'])
    n_ep           = len(hist.history['val_accuracy'])
    best_precision = max(hist.history['val_precision'])
    print(f'{label:30s}  epochs={n_ep:2d}  val_acc={best_acc:.4f}  val_loss={best_loss:.4f}   val_precision={best_precision:.4f}')

print('\n── Output files ───────────────────────────────────────')
for fname in sorted(os.listdir(OUTPUT_DIR)):
    fpath = os.path.join(OUTPUT_DIR, fname)
    if os.path.isfile(fpath):
        kb = os.path.getsize(fpath) / 1024
        print(f'  {fname:<45s} {kb:>8.0f} KB')
# Out:
# ── All phase results ──────────────────────────────────
# Phase 1 (FER-13 7e-4)           epochs= 5  val_acc=0.1503  val_loss=2.1832   val_precision=0.1385
# Phase 2 (FER-13 7e-4)           epochs=15  val_acc=0.6605  val_loss=1.2045   val_precision=0.7431
# Phase 3 (FER-13 3e-6)           epochs=18  val_acc=0.6556  val_loss=1.2235   val_precision=0.7145
# Phase 4 (RAF-DB 3e-6)           epochs=72  val_acc=0.7435  val_loss=1.0353   val_precision=0.8133
# Phase 5 (AFD-DB 5e-6)           epochs=64  val_acc=0.8988  val_loss=0.7107   val_precision=0.9187
#
# ── Output files ───────────────────────────────────────
#   10th_trial_confusion_matrices.png                  128 KB
#   afd_tflite_confusion_matrix.png                     54 KB
#   base_model.keras                                 12412 KB
#   fer13_tflite_confusion_matrix.png                   66 KB
#   final_qat_int8.tflite                             3220 KB
#   phase1_all_frozen_best.keras                     12424 KB
#   phase1_all_frozen_final_accuracy_0.1503.keras    12412 KB
#   phase1_all_frozen_log.csv                            1 KB
#   phase2_top90_frozen_best.keras                   34141 KB
#   phase2_top90_frozen_final_accuracy_0.6605.keras    12412 KB
#   phase2_top90_frozen_log.csv                          2 KB
#   phase3_top40_frozen_best.keras                   35782 KB
#   phase3_top40_frozen_final_accuracy_0.6556.keras    12412 KB
#   phase3_top40_frozen_log.csv                          2 KB
#   phase4_rafdb_best.keras                          35782 KB
#   phase4_rafdb_final_accuracy_0.7435.keras         12412 KB
#   phase4_rafdb_log.csv                                 0 KB
#   phase5_afd_best.keras                            35782 KB
#   phase5_afd_final_accuracy_0.8988.keras           12412 KB
#   phase5_afd_log.csv                                   8 KB
#   rafdb_tflite_confusion_matrix.png                   65 KB
#   training_curves.png                                154 KB
